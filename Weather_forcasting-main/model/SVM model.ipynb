# %% [markdown]
# # I. First initiation

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import mutual_info_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing dataset

# %%
#Set display options to show all columns
pd.set_option('display.max_columns', None)

#Upload dataset
df = pd.read_csv("../data/raw/dataset.csv")
df = df.drop(df.columns[0], axis=1)

# %%
df.head(20)
# Out:
#        forecast_time_07 forecast_date_07       city_name  latitude  \
# 0   2024-02-08 19:00:00       2024-02-08      TP. HÀ NỘI   21.0245
# 1   2024-02-08 22:00:00       2024-02-08      TP. HÀ NỘI   21.0245
# 2   2024-02-08 19:00:00       2024-02-08    TỈNH BẮC KẠN   22.1333
# 3   2024-02-08 22:00:00       2024-02-08    TỈNH BẮC KẠN   22.1333
# 4   2024-02-08 19:00:00       2024-02-08  TỈNH BẮC GIANG   21.2731
# 5   2024-02-08 22:00:00       2024-02-08  TỈNH BẮC GIANG   21.2731
# 6   2024-02-08 19:00:00       2024-02-08   TỈNH BẮC NINH   21.1861
# 7   2024-02-08 22:00:00       2024-02-08   TỈNH BẮC NINH   21.1861
# 8   2024-02-08 22:00:00       2024-02-08   TỈNH CAO BẰNG   22.6731
# 9   2024-02-08 19:00:00       2024-02-08   TỈNH CAO BẰNG   22.6731
# 10  2024-02-08 19:00:00       2024-02-08   TỈNH HÀ GIANG   22.8233
# 11  2024-02-08 22:00:00       2024-02-08   TỈNH HÀ GIANG   22.8233
# 12  2024-02-08 22:00:00       2024-02-08   TỈNH HƯNG YÊN   20.6464
# 13  2024-02-08 19:00:00       2024-02-08   TỈNH HƯNG YÊN   20.6464
# 14  2024-02-08 22:00:00       2024-02-08   TỈNH LAI CHÂU   22.3991
# 15  2024-02-08 19:00:00       2024-02-08   TỈNH LAI CHÂU   22.3991
# 16  2024-02-08 19:00:00       2024-02-08   TỈNH LẠNG SƠN   21.8535
# 17  2024-02-08 22:00:00       2024-02-08   TỈNH LẠNG SƠN   21.8535
# 18  2024-02-08 19:00:00       2024-02-08    TỈNH LÀO CAI   22.4194
# 19  2024-02-08 22:00:00       2024-02-08    TỈNH LÀO CAI   22.4194
#
#     longtitude   temp  feels_like  temp_min  temp_max  pressure  sea_level  \
# 0     105.8410  14.00       13.31     13.13     14.00    1018.0     1018.0
# 1     105.8410  13.60       12.84     12.81     13.60    1019.0     1019.0
# 2     105.8333  10.89       10.20     10.89     10.89    1019.0     1019.0
# 3     105.8333  10.74       10.04     10.45     10.74    1020.0     1020.0
# 4     106.1947  14.01       13.29     12.34     14.01    1018.0     1018.0
# 5     106.1947  13.43       12.63     12.26     13.43    1019.0     1019.0
# 6     106.0763  14.03       13.34     12.61     14.03    1018.0     1018.0
# 7     106.0763  13.54       12.78     12.55     13.54    1019.0     1019.0
# 8     106.2500  10.85       10.00     10.85     10.98    1022.0     1022.0
# 9     106.2500  10.78        9.95     10.78     10.78    1021.0     1021.0
# 10    104.9836  14.36       14.15     14.36     14.36    1018.0     1018.0
# 11    104.9836  14.33       14.12     14.28     14.33    1019.0     1019.0
# 12    106.0511  13.19       12.52     12.73     13.19    1019.0     1019.0
# 13    106.0511  13.42       12.80     13.42     13.42    1018.0     1018.0
# 14    103.4393  16.58       15.94     13.54     16.58    1012.0     1012.0
# 15    103.4393  18.10       17.43     18.10     18.10    1011.0     1011.0
# 16    106.7589   8.65        6.79      8.65      8.65    1020.0     1020.0
# 17    106.7589   8.57        6.82      8.40      8.57    1021.0     1021.0
# 18    103.9950  15.60       15.54     15.60     15.60    1016.0     1016.0
# 19    103.9950  15.34       15.25     14.82     15.34    1017.0     1017.0
#
#     grnd_level  temp_kf  humidity  probability_of_precipitation  \
# 0       1017.0     0.87      71.0                          0.00
# 1       1019.0     0.79      70.0                          0.00
# 2        999.0     0.00      83.0                          0.00
# 3       1001.0     0.29      83.0                          0.00
# 4       1017.0     1.67      70.0                          0.00
# 5       1019.0     1.17      69.0                          0.00
# 6       1017.0     1.42      71.0                          0.00
# 7       1020.0     0.99      70.0                          0.00
# 8       1000.0    -0.13      77.0                          0.00
# 9        998.0     0.00      78.0                          0.00
# 10      1003.0     0.00      88.0                          0.00
# 11      1006.0     0.05      88.0                          0.00
# 12      1019.0     0.46      75.0                          0.04
# 13      1017.0     0.00      76.0                          0.00
# 14       911.0     3.04      63.0                          0.00
# 15       909.0     0.00      56.0                          0.00
# 16       989.0     0.00      80.0                          0.00
# 17       990.0     0.17      80.0                          0.00
# 18       997.0     0.00      89.0                          0.00
# 19       999.0     0.52      89.0                          0.00
#
#    unit_of_precipitation  value_of_precipitation weather_main  \
# 0                     3h                     0.0       Clouds
# 1                     3h                     0.0       Clouds
# 2                     3h                     0.0       Clouds
# 3                     3h                     0.0       Clouds
# 4                     3h                     0.0       Clouds
# 5                     3h                     0.0       Clouds
# 6                     3h                     0.0       Clouds
# 7                     3h                     0.0       Clouds
# 8                     3h                     0.0       Clouds
# 9                     3h                     0.0       Clouds
# 10                    3h                     0.0       Clouds
# 11                    3h                     0.0       Clouds
# 12                    3h                     0.0       Clouds
# 13                    3h                     0.0       Clouds
# 14                    3h                     0.0        Clear
# 15                    3h                     0.0        Clear
# 16                    3h                     0.0       Clouds
# 17                    3h                     0.0       Clouds
# 18                    3h                     0.0       Clouds
# 19                    3h                     0.0       Clouds
#
#     weather_description  wind_speed  wind_deg  wind_gust  visibility  \
# 0          mây đen u ám        3.85      30.0       6.22     10000.0
# 1          mây đen u ám        3.04      28.0       5.60     10000.0
# 2          mây đen u ám        1.65      63.0       4.46     10000.0
# 3          mây đen u ám        1.62      57.0       4.73     10000.0
# 4          mây đen u ám        4.34      33.0       7.24     10000.0
# 5          mây đen u ám        4.15      29.0       6.99     10000.0
# 6          mây đen u ám        4.48      28.0       7.05     10000.0
# 7          mây đen u ám        4.03      24.0       6.72     10000.0
# 8          mây đen u ám        0.95      54.0       2.56     10000.0
# 9          mây đen u ám        1.44     100.0       3.35     10000.0
# 10         mây đen u ám        0.40      93.0       0.74     10000.0
# 11         mây đen u ám        0.34      39.0       0.77     10000.0
# 12         mây đen u ám        3.08     349.0       4.58     10000.0
# 13         mây đen u ám        3.28     353.0       4.77     10000.0
# 14  bầu trời quang đãng        2.24      76.0       3.34     10000.0
# 15  bầu trời quang đãng        1.66      83.0       1.58     10000.0
# 16         mây đen u ám        3.16      34.0       7.00     10000.0
# 17         mây đen u ám        2.96      29.0       7.17     10000.0
# 18              mây cụm        1.59     128.0       4.18     10000.0
# 19              mây cụm        1.33     121.0       3.67     10000.0
#
#                   __updated_at
# 0   2024-02-08 18:53:32.227763
# 1   2024-02-08 18:53:32.227955
# 2   2024-02-08 18:53:32.229873
# 3   2024-02-08 18:53:32.229873
# 4   2024-02-08 18:53:32.230857
# 5   2024-02-08 18:53:32.230857
# 6   2024-02-08 18:53:32.232857
# 7   2024-02-08 18:53:32.232857
# 8   2024-02-08 18:53:32.233840
# 9   2024-02-08 18:53:32.233840
# 10  2024-02-08 18:53:32.235854
# 11  2024-02-08 18:53:32.235854
# 12  2024-02-08 18:53:32.236852
# 13  2024-02-08 18:53:32.236852
# 14  2024-02-08 18:53:32.238433
# 15  2024-02-08 18:53:32.238433
# 16  2024-02-08 18:53:32.240439
# 17  2024-02-08 18:53:32.240439
# 18  2024-02-08 18:53:32.241530
# 19  2024-02-08 18:53:32.241530

# %%
df.shape
# Out:
# (120645, 24)

# %% [markdown]
# => The dataset has 115675 rows and 24 columns

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120645 entries, 0 to 120644
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   forecast_time_07              120645 non-null  object
#  1   forecast_date_07              120645 non-null  object
#  2   city_name                     120645 non-null  object
#  3   latitude                      120645 non-null  float64
#  4   longtitude                    120645 non-null  float64
#  5   temp                          120645 non-null  float64
#  6   feels_like                    120645 non-null  float64
#  7   temp_min                      120645 non-null  float64
#  8   temp_max                      120645 non-null  float64
#  9   pressure                      120645 non-null  float64
#  10  sea_level                     120645 non-null  float64
#  11  grnd_level                    120645 non-null  float64
#  12  temp_kf                       120645 non-null  float64
#  13  humidity                      120645 non-null  float64
#  14  probability_of_precipitation  120645 non-null  float64
#  15  unit_of_precipitation         120645 non-null  object
#  16  value_of_precipitation        120645 non-null  float64
#  17  weather_main                  120645 non-null  object
#  18  weather_description           120645 non-null  object
#  19  wind_speed                    120645 non-null  float64
#  20  wind_deg                      120645 non-null  float64
#  21  wind_gust                     120645 non-null  float64
#  22  visibility                    120645 non-null  float64
#  23  __updated_at                  120645 non-null  object
# dtypes: float64(17), object(7)
# memory usage: 22.1+ MB
# None

# %% [markdown]
# # II. Preprocess

# %% [markdown]
# ## Cleaning dataset

# %% [markdown]
# As we can see, the forecast_time_07 and forecast_date_07 do have the date in common. So now we elcreate a new column only for time observations

# %%
df['ftime'] = pd.to_datetime(df['forecast_time_07']).dt.time

# %%
df.head(20)
# Out:
#        forecast_time_07 forecast_date_07       city_name  latitude  \
# 0   2024-02-08 19:00:00       2024-02-08      TP. HÀ NỘI   21.0245
# 1   2024-02-08 22:00:00       2024-02-08      TP. HÀ NỘI   21.0245
# 2   2024-02-08 19:00:00       2024-02-08    TỈNH BẮC KẠN   22.1333
# 3   2024-02-08 22:00:00       2024-02-08    TỈNH BẮC KẠN   22.1333
# 4   2024-02-08 19:00:00       2024-02-08  TỈNH BẮC GIANG   21.2731
# 5   2024-02-08 22:00:00       2024-02-08  TỈNH BẮC GIANG   21.2731
# 6   2024-02-08 19:00:00       2024-02-08   TỈNH BẮC NINH   21.1861
# 7   2024-02-08 22:00:00       2024-02-08   TỈNH BẮC NINH   21.1861
# 8   2024-02-08 22:00:00       2024-02-08   TỈNH CAO BẰNG   22.6731
# 9   2024-02-08 19:00:00       2024-02-08   TỈNH CAO BẰNG   22.6731
# 10  2024-02-08 19:00:00       2024-02-08   TỈNH HÀ GIANG   22.8233
# 11  2024-02-08 22:00:00       2024-02-08   TỈNH HÀ GIANG   22.8233
# 12  2024-02-08 22:00:00       2024-02-08   TỈNH HƯNG YÊN   20.6464
# 13  2024-02-08 19:00:00       2024-02-08   TỈNH HƯNG YÊN   20.6464
# 14  2024-02-08 22:00:00       2024-02-08   TỈNH LAI CHÂU   22.3991
# 15  2024-02-08 19:00:00       2024-02-08   TỈNH LAI CHÂU   22.3991
# 16  2024-02-08 19:00:00       2024-02-08   TỈNH LẠNG SƠN   21.8535
# 17  2024-02-08 22:00:00       2024-02-08   TỈNH LẠNG SƠN   21.8535
# 18  2024-02-08 19:00:00       2024-02-08    TỈNH LÀO CAI   22.4194
# 19  2024-02-08 22:00:00       2024-02-08    TỈNH LÀO CAI   22.4194
#
#     longtitude   temp  feels_like  temp_min  temp_max  pressure  sea_level  \
# 0     105.8410  14.00       13.31     13.13     14.00    1018.0     1018.0
# 1     105.8410  13.60       12.84     12.81     13.60    1019.0     1019.0
# 2     105.8333  10.89       10.20     10.89     10.89    1019.0     1019.0
# 3     105.8333  10.74       10.04     10.45     10.74    1020.0     1020.0
# 4     106.1947  14.01       13.29     12.34     14.01    1018.0     1018.0
# 5     106.1947  13.43       12.63     12.26     13.43    1019.0     1019.0
# 6     106.0763  14.03       13.34     12.61     14.03    1018.0     1018.0
# 7     106.0763  13.54       12.78     12.55     13.54    1019.0     1019.0
# 8     106.2500  10.85       10.00     10.85     10.98    1022.0     1022.0
# 9     106.2500  10.78        9.95     10.78     10.78    1021.0     1021.0
# 10    104.9836  14.36       14.15     14.36     14.36    1018.0     1018.0
# 11    104.9836  14.33       14.12     14.28     14.33    1019.0     1019.0
# 12    106.0511  13.19       12.52     12.73     13.19    1019.0     1019.0
# 13    106.0511  13.42       12.80     13.42     13.42    1018.0     1018.0
# 14    103.4393  16.58       15.94     13.54     16.58    1012.0     1012.0
# 15    103.4393  18.10       17.43     18.10     18.10    1011.0     1011.0
# 16    106.7589   8.65        6.79      8.65      8.65    1020.0     1020.0
# 17    106.7589   8.57        6.82      8.40      8.57    1021.0     1021.0
# 18    103.9950  15.60       15.54     15.60     15.60    1016.0     1016.0
# 19    103.9950  15.34       15.25     14.82     15.34    1017.0     1017.0
#
#     grnd_level  temp_kf  humidity  probability_of_precipitation  \
# 0       1017.0     0.87      71.0                          0.00
# 1       1019.0     0.79      70.0                          0.00
# 2        999.0     0.00      83.0                          0.00
# 3       1001.0     0.29      83.0                          0.00
# 4       1017.0     1.67      70.0                          0.00
# 5       1019.0     1.17      69.0                          0.00
# 6       1017.0     1.42      71.0                          0.00
# 7       1020.0     0.99      70.0                          0.00
# 8       1000.0    -0.13      77.0                          0.00
# 9        998.0     0.00      78.0                          0.00
# 10      1003.0     0.00      88.0                          0.00
# 11      1006.0     0.05      88.0                          0.00
# 12      1019.0     0.46      75.0                          0.04
# 13      1017.0     0.00      76.0                          0.00
# 14       911.0     3.04      63.0                          0.00
# 15       909.0     0.00      56.0                          0.00
# 16       989.0     0.00      80.0                          0.00
# 17       990.0     0.17      80.0                          0.00
# 18       997.0     0.00      89.0                          0.00
# 19       999.0     0.52      89.0                          0.00
#
#    unit_of_precipitation  value_of_precipitation weather_main  \
# 0                     3h                     0.0       Clouds
# 1                     3h                     0.0       Clouds
# 2                     3h                     0.0       Clouds
# 3                     3h                     0.0       Clouds
# 4                     3h                     0.0       Clouds
# 5                     3h                     0.0       Clouds
# 6                     3h                     0.0       Clouds
# 7                     3h                     0.0       Clouds
# 8                     3h                     0.0       Clouds
# 9                     3h                     0.0       Clouds
# 10                    3h                     0.0       Clouds
# 11                    3h                     0.0       Clouds
# 12                    3h                     0.0       Clouds
# 13                    3h                     0.0       Clouds
# 14                    3h                     0.0        Clear
# 15                    3h                     0.0        Clear
# 16                    3h                     0.0       Clouds
# 17                    3h                     0.0       Clouds
# 18                    3h                     0.0       Clouds
# 19                    3h                     0.0       Clouds
#
#     weather_description  wind_speed  wind_deg  wind_gust  visibility  \
# 0          mây đen u ám        3.85      30.0       6.22     10000.0
# 1          mây đen u ám        3.04      28.0       5.60     10000.0
# 2          mây đen u ám        1.65      63.0       4.46     10000.0
# 3          mây đen u ám        1.62      57.0       4.73     10000.0
# 4          mây đen u ám        4.34      33.0       7.24     10000.0
# 5          mây đen u ám        4.15      29.0       6.99     10000.0
# 6          mây đen u ám        4.48      28.0       7.05     10000.0
# 7          mây đen u ám        4.03      24.0       6.72     10000.0
# 8          mây đen u ám        0.95      54.0       2.56     10000.0
# 9          mây đen u ám        1.44     100.0       3.35     10000.0
# 10         mây đen u ám        0.40      93.0       0.74     10000.0
# 11         mây đen u ám        0.34      39.0       0.77     10000.0
# 12         mây đen u ám        3.08     349.0       4.58     10000.0
# 13         mây đen u ám        3.28     353.0       4.77     10000.0
# 14  bầu trời quang đãng        2.24      76.0       3.34     10000.0
# 15  bầu trời quang đãng        1.66      83.0       1.58     10000.0
# 16         mây đen u ám        3.16      34.0       7.00     10000.0
# 17         mây đen u ám        2.96      29.0       7.17     10000.0
# 18              mây cụm        1.59     128.0       4.18     10000.0
# 19              mây cụm        1.33     121.0       3.67     10000.0
#
#                   __updated_at     ftime
# 0   2024-02-08 18:53:32.227763  19:00:00
# 1   2024-02-08 18:53:32.227955  22:00:00
# 2   2024-02-08 18:53:32.229873  19:00:00
# 3   2024-02-08 18:53:32.229873  22:00:00
# 4   2024-02-08 18:53:32.230857  19:00:00
# 5   2024-02-08 18:53:32.230857  22:00:00
# 6   2024-02-08 18:53:32.232857  19:00:00
# 7   2024-02-08 18:53:32.232857  22:00:00
# 8   2024-02-08 18:53:32.233840  22:00:00
# 9   2024-02-08 18:53:32.233840  19:00:00
# 10  2024-02-08 18:53:32.235854  19:00:00
# 11  2024-02-08 18:53:32.235854  22:00:00
# 12  2024-02-08 18:53:32.236852  22:00:00
# 13  2024-02-08 18:53:32.236852  19:00:00
# 14  2024-02-08 18:53:32.238433  22:00:00
# 15  2024-02-08 18:53:32.238433  19:00:00
# 16  2024-02-08 18:53:32.240439  19:00:00
# 17  2024-02-08 18:53:32.240439  22:00:00
# 18  2024-02-08 18:53:32.241530  19:00:00
# 19  2024-02-08 18:53:32.241530  22:00:00

# %% [markdown]
# ## Labeling output

# %% [markdown]
# We can see in dataset that the weather_main shows 3 results of weather which are: clouds, clear and rain. Thus, we can use this column to display output label for model.

# %% [markdown]
# Because weather_main has object datatype, so we need to convert it into numerical values by using Label Encoding

# %%
#Labeling output data
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['weather_main_encoded'] = label_encoder.fit_transform(df['weather_main'])

#Inspecting labels
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label mapping:")
print(label_mapping)
# Out:
# Label mapping:
# {'Clear': 0, 'Clouds': 1, 'Rain': 2}

# %% [markdown]
# ## Reducing reduntdant columns

# %% [markdown]
# Also we need to eliminate some redundant features to ensure that our model works properly. By exprience we can show that weather_description and visibility have nothing efffects on our model. So let's drop those columns. Consider that the unit_of_precipitation data only indicates the measured-period time for precipitation. So we can drop this column due to its low impact on our model.

# %%
# Drop the redundant columns
redundant_columns = ['weather_description', 'visibility', 'unit_of_precipitation']
df_reduced = df.drop(columns=redundant_columns)

# %% [markdown]
# After that, we need to reformat the time and date in columns 'forecast_time_07', 'forecast_date_07'.

# %%
df['forecast_time_07'] = pd.to_datetime(df['forecast_time_07'])
df['forecast_date_07'] = pd.to_datetime(df['forecast_date_07'])
#df['_updated_at']      = pd.to_datetime(df['_updated_at'])

# %% [markdown]
# ## Handling missing values

# %% [markdown]
# Now we come to next stage, identifying missing data.

# %%
#Identify missing values
missing_data = df.isnull().sum()
print("Missing values in each column: ")
print(missing_data)

#Percentage of missing values
missing_data_percent = (df.isnull().sum() / len(df))*100
print("Percentage of missing values in each column: ")
print(missing_data_percent)
# Out:
# Missing values in each column:
# forecast_time_07                0
# forecast_date_07                0
# city_name                       0
# latitude                        0
# longtitude                      0
# temp                            0
# feels_like                      0
# temp_min                        0
# temp_max                        0
# pressure                        0
# sea_level                       0
# grnd_level                      0
# temp_kf                         0
# humidity                        0
# probability_of_precipitation    0
# unit_of_precipitation           0
# value_of_precipitation          0
# weather_main                    0
# weather_description             0
# wind_speed                      0
# wind_deg                        0
# wind_gust                       0
# visibility                      0
# __updated_at                    0
# ftime                           0
# weather_main_encoded            0
# dtype: int64
# Percentage of missing values in each column:
# forecast_time_07                0.0
# forecast_date_07                0.0
# city_name                       0.0
# latitude                        0.0
# longtitude                      0.0
# temp                            0.0
# feels_like                      0.0
# temp_min                        0.0
# temp_max                        0.0
# pressure                        0.0
# sea_level                       0.0
# grnd_level                      0.0
# temp_kf                         0.0
# humidity                        0.0
# probability_of_precipitation    0.0
# unit_of_precipitation           0.0
# value_of_precipitation          0.0
# weather_main                    0.0
# weather_description             0.0
# wind_speed                      0.0
# wind_deg                        0.0
# wind_gust                       0.0
# visibility                      0.0
# __updated_at                    0.0
# ftime                           0.0
# weather_main_encoded            0.0
# dtype: float64

# %% [markdown]
# Retriving the result that there are no missing values in our dataset, we move to the next step.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Visualizing data

# %% [markdown]
# ### Overview histograms

# %%
numerical_columns = ['latitude', 'longtitude', 'temp', 'feels_like', 'temp_min', 'temp_max',
                     'pressure', 'sea_level', 'grnd_level', 'humidity', 'weather_main_encoded',
                     'probability_of_precipitation', 'value_of_precipitation',
                     'wind_speed', 'wind_deg', 'wind_gust']

#Creating histograms
plt.figure(figsize=(20,15))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(4, 4, i)
    df[column].hist(bins = 30, edgecolor = 'black')
    plt.title(f"Histogram of {column}")
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data relevance

# %% [markdown]
# ### Observation time

# %%
# Expected forecast times
expected_times = [
    '00:00:00', '01:00:00', '02:00:00', '03:00:00', '04:00:00',
    '05:00:00', '06:00:00', '07:00:00', '08:00:00', '09:00:00',
    '10:00:00', '11:00:00', '12:00:00', '13:00:00', '14:00:00',
    '15:00:00', '16:00:00', '17:00:00', '18:00:00', '19:00:00',
    '20:00:00', '21:00:00', '22:00:00', '23:00:00'
]

# Convert expected times to datetime.time objects
expected_times = [pd.to_datetime(time).time() for time in expected_times]

# Create a DataFrame with expected times
expected_df = pd.DataFrame(expected_times, columns=['ftime'])

# Count the number of observations for each time
count_time = df['ftime'].value_counts().sort_index()

# %%
# Create a DataFrame for counts
count_df = pd.DataFrame(count_time).reset_index()
count_df.columns = ['ftime', 'count']

# %%
# Merge with expected times to include missing times
merged_df = expected_df.merge(count_df, on='ftime', how='left').fillna(0)

# Plot the frequency of each forecast time
plt.figure(figsize=(12, 8))
plt.bar(merged_df['ftime'].astype(str), merged_df['count'], color='skyblue')
plt.title('Frequency of Forecast Times')
plt.xlabel('Time of the Day')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# The plot reveals that the dataset lacks observations in specific times, notably 2:00, 5:00, 8:00, 11:00, 14:00, 17:00, 20:00, 23:00. Which suggests the way data is colleted. However, looking into the number of observations in each time, we can see that the dataset has a good variation in every other time.

# %% [markdown]
# ### Location observations

# %%
# Count the occurrences of each location
location_counts = df['city_name'].value_counts()

# %%
# Plot the number of observations in each location
plt.figure(figsize=(15, 6))
location_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Observations in Each Location')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right', fontsize = 5 )
plt.show()

# %% [markdown]
# ### Multiple features data relevances

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='humidity', y='temp', hue='weather_main', data=df)
plt.title('Relationship Between Humidity and Temperature')
plt.xlabel('Humidity')
plt.ylabel('Temperature')
plt.legend(title='Weather Condition')
plt.show()

# %%
df_reduced = df.drop(columns=redundant_columns)
df_reduced.head()
# Out:
#      forecast_time_07 forecast_date_07       city_name  latitude  longtitude  \
# 0 2024-02-08 19:00:00       2024-02-08      TP. HÀ NỘI   21.0245    105.8410
# 1 2024-02-08 22:00:00       2024-02-08      TP. HÀ NỘI   21.0245    105.8410
# 2 2024-02-08 19:00:00       2024-02-08    TỈNH BẮC KẠN   22.1333    105.8333
# 3 2024-02-08 22:00:00       2024-02-08    TỈNH BẮC KẠN   22.1333    105.8333
# 4 2024-02-08 19:00:00       2024-02-08  TỈNH BẮC GIANG   21.2731    106.1947
#
#     temp  feels_like  temp_min  temp_max  pressure  sea_level  grnd_level  \
# 0  14.00       13.31     13.13     14.00    1018.0     1018.0      1017.0
# 1  13.60       12.84     12.81     13.60    1019.0     1019.0      1019.0
# 2  10.89       10.20     10.89     10.89    1019.0     1019.0       999.0
# 3  10.74       10.04     10.45     10.74    1020.0     1020.0      1001.0
# 4  14.01       13.29     12.34     14.01    1018.0     1018.0      1017.0
#
#    temp_kf  humidity  probability_of_precipitation  value_of_precipitation  \
# 0     0.87      71.0                           0.0                     0.0
# 1     0.79      70.0                           0.0                     0.0
# 2     0.00      83.0                           0.0                     0.0
# 3     0.29      83.0                           0.0                     0.0
# 4     1.67      70.0                           0.0                     0.0
#
#   weather_main  wind_speed  wind_deg  wind_gust                __updated_at  \
# 0       Clouds        3.85      30.0       6.22  2024-02-08 18:53:32.227763
# 1       Clouds        3.04      28.0       5.60  2024-02-08 18:53:32.227955
# 2       Clouds        1.65      63.0       4.46  2024-02-08 18:53:32.229873
# 3       Clouds        1.62      57.0       4.73  2024-02-08 18:53:32.229873
# 4       Clouds        4.34      33.0       7.24  2024-02-08 18:53:32.230857
#
#       ftime  weather_main_encoded
# 0  19:00:00                     1
# 1  22:00:00                     1
# 2  19:00:00                     1
# 3  22:00:00                     1
# 4  19:00:00                     1

# %%
x = df_reduced.copy()
x = x.drop(columns = 'forecast_time_07')
x = x.drop(columns = 'forecast_date_07')
x = x.drop(columns = '__updated_at')
x = x.drop(columns = 'weather_main')
y = x.pop('weather_main_encoded')

# %%
for colname in x.select_dtypes('object'):
  x[colname], _ = x[colname].factorize()

discrete_features = x.dtypes == int

print(x.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120645 entries, 0 to 120644
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   city_name                     120645 non-null  int64
#  1   latitude                      120645 non-null  float64
#  2   longtitude                    120645 non-null  float64
#  3   temp                          120645 non-null  float64
#  4   feels_like                    120645 non-null  float64
#  5   temp_min                      120645 non-null  float64
#  6   temp_max                      120645 non-null  float64
#  7   pressure                      120645 non-null  float64
#  8   sea_level                     120645 non-null  float64
#  9   grnd_level                    120645 non-null  float64
#  10  temp_kf                       120645 non-null  float64
#  11  humidity                      120645 non-null  float64
#  12  probability_of_precipitation  120645 non-null  float64
#  13  value_of_precipitation        120645 non-null  float64
#  14  wind_speed                    120645 non-null  float64
#  15  wind_deg                      120645 non-null  float64
#  16  wind_gust                     120645 non-null  float64
#  17  ftime                         120645 non-null  int64
# dtypes: float64(16), int64(2)
# memory usage: 16.6 MB
# None

# %%
from sklearn.feature_selection import mutual_info_classif

def make_mi_scores(x, y, discrete_features):
  mi_scores = mutual_info_classif(x, y, discrete_features=discrete_features)
  mi_scores = pd.Series(mi_scores, name="MI Scores", index=x.columns)
  mi_scores = mi_scores.sort_values(ascending=False)
  return mi_scores

mi_scores = make_mi_scores(x, y, discrete_features)
print(mi_scores)
# Out:
# value_of_precipitation          0.552713
# probability_of_precipitation    0.456188
# humidity                        0.072787
# latitude                        0.046780
# city_name                       0.043892
# longtitude                      0.043430
# grnd_level                      0.030693
# pressure                        0.026170
# sea_level                       0.024365
# temp_kf                         0.022653
# temp_max                        0.018510
# temp                            0.017171
# temp_min                        0.015959
# feels_like                      0.014448
# wind_deg                        0.012566
# wind_gust                       0.006293
# wind_speed                      0.005906
# ftime                           0.004639
# Name: MI Scores, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
print(x_scaled)
# Out:
# [[0.         0.86818502 0.44873608 ... 0.08333333 0.31141692 0.        ]
#  [0.         0.86818502 0.44873608 ... 0.07777778 0.27981651 0.06666667]
#  [0.01612903 0.94943721 0.44751267 ... 0.175      0.22171254 0.        ]
#  ...
#  [0.20967742 0.86207351 0.52692289 ... 0.34166667 0.52395515 0.73333333]
#  [0.20967742 0.86207351 0.52692289 ... 0.31388889 0.44546381 0.8       ]
#  [0.20967742 0.86207351 0.52692289 ... 0.30555556 0.48776758 0.86666667]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
print(x_scaled)
# Out:
# [[-1.70477271  1.01739886 -0.39731806 ... -1.2611185   0.51466018
#   -2.6091808 ]
#  [-1.70477271  1.01739886 -0.39731806 ... -1.28496736  0.31239421
#   -2.34922652]
#  [-1.64978004  1.2447434  -0.40290865 ... -0.86761231 -0.05951419
#   -2.6091808 ]
#  ...
#  [-0.98986803  1.00029881 -0.0400282  ... -0.15214651  1.87506195
#    0.25031629]
#  [-0.98986803  1.00029881 -0.0400282  ... -0.27139081  1.37265938
#    0.51027057]
#  [-0.98986803  1.00029881 -0.0400282  ... -0.3071641   1.64343479
#    0.77022485]]

# %%
df_reduced.columns
# Out:
# Index(['forecast_time_07', 'forecast_date_07', 'city_name', 'latitude',
#        'longtitude', 'temp', 'feels_like', 'temp_min', 'temp_max', 'pressure',
#        'sea_level', 'grnd_level', 'temp_kf', 'humidity',
#        'probability_of_precipitation', 'value_of_precipitation',
#        'weather_main', 'wind_speed', 'wind_deg', 'wind_gust', '__updated_at',
#        'ftime', 'weather_main_encoded'],
#       dtype='object')

# %% [markdown]
# # III. Methods

# %% [markdown]
# ## SVM

# %%
df_reduced['hour'] = df_reduced['forecast_time_07'].dt.strftime("%H").apply(lambda x: int(x))

# %%
import pandas as pd
y = df_reduced['weather_main_encoded']
label_counts = y.value_counts()

print(label_counts)
# Out:
# weather_main_encoded
# 1    81597
# 2    29087
# 0     9961
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='weather_main_encoded', data=df)
plt.title('Phân bố weather_main')
plt.xlabel('Weather Main')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1, 2], labels=label_encoder.classes_)
plt.show()

# %%
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from collections import Counter

selected_features = ["temp",
"pressure",
"grnd_level",
"temp_kf",
"humidity",
"probability_of_precipitation",
"value_of_precipitation",
"wind_speed",
"wind_deg",
"wind_gust",
"visibility"
]
X = df[selected_features]
y = df['weather_main_encoded']

rus = RandomUnderSampler(sampling_strategy='not minority', random_state=42)
X_resampled, y_resampled = rus.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# %%
import matplotlib.pyplot as plt
counts = balanced_data['Label'].value_counts()

plt.figure(figsize=(8, 6))
counts.plot(kind='bar')
plt.title('Số lượng mẫu của mỗi nhãn sau khi undersampling')
plt.xlabel('Nhãn')
plt.ylabel('Số lượng mẫu')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 0 - clear
# 1 - clouds
# 2 - rain

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
model = SVC(kernel = 'linear', C = 1.0, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.51      0.55      1992
#            1       0.54      0.64      0.59      1992
#            2       0.97      0.91      0.94      1993
#
#     accuracy                           0.69      5977
#    macro avg       0.70      0.69      0.69      5977
# weighted avg       0.70      0.69      0.69      5977

# %%
from sklearn.metrics import accuracy_score
print("- Testing ...")
y_pred = model.predict(X_test)
print("- Acc = {}".format(accuracy_score(y_test, y_pred)))
# Out:
# - Testing ...
# - Acc = 0.6894763259160114
